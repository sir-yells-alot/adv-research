# %%
# %reset -f
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr

# %% [markdown]
# Task 1 Code

# %%
power_data_1 = pd.read_csv("Plant_1_Generation_Data.csv")
weather_data_1 = pd.read_csv("Plant_1_Weather_Sensor_Data.csv")
power_data_2 = pd.read_csv("Plant_2_Generation_Data.csv")
weather_data_2 = pd.read_csv("Plant_2_Weather_Sensor_Data.csv")

# Only this file has a different date time format for some reason
power_data_1['DATE_TIME'] = pd.to_datetime(power_data_1['DATE_TIME'], format="%d-%m-%Y %H:%M")

power_data_2['DATE_TIME'] = pd.to_datetime(power_data_2['DATE_TIME'], format="%Y-%m-%d %H:%M:%S")

weather_data_1['DATE_TIME'] = pd.to_datetime(weather_data_1['DATE_TIME'], format="%Y-%m-%d %H:%M:%S")
weather_data_2['DATE_TIME']= pd.to_datetime(weather_data_2['DATE_TIME'], format="%Y-%m-%d %H:%M:%S")

# Merge power and weather data simply via concatenation
power_data = pd.concat([power_data_1, power_data_2])
weather_data = pd.concat([weather_data_1, weather_data_2])

display(power_data, weather_data)
# Out:
#                 DATE_TIME  PLANT_ID  ... DAILY_YIELD  TOTAL_YIELD
# 0     2020-05-15 00:00:00   4135001  ...         0.0    6259559.0
# 1     2020-05-15 00:00:00   4135001  ...         0.0    6183645.0
# 2     2020-05-15 00:00:00   4135001  ...         0.0    6987759.0
# 3     2020-05-15 00:00:00   4135001  ...         0.0    7602960.0
# 4     2020-05-15 00:00:00   4135001  ...         0.0    7158964.0
# ...                   ...       ...  ...         ...          ...
# 67693 2020-06-17 23:45:00   4136001  ...      4157.0     520758.0
# 67694 2020-06-17 23:45:00   4136001  ...      3931.0  121131356.0
# 67695 2020-06-17 23:45:00   4136001  ...      4322.0    2427691.0
# 67696 2020-06-17 23:45:00   4136001  ...      4218.0  106896394.0
# 67697 2020-06-17 23:45:00   4136001  ...      4316.0  209335741.0
#
# [136476 rows x 7 columns]
#                DATE_TIME  PLANT_ID  ... MODULE_TEMPERATURE  IRRADIATION
# 0    2020-05-15 00:00:00   4135001  ...          22.857507          0.0
# 1    2020-05-15 00:15:00   4135001  ...          22.761668          0.0
# 2    2020-05-15 00:30:00   4135001  ...          22.592306          0.0
# 3    2020-05-15 00:45:00   4135001  ...          22.360852          0.0
# 4    2020-05-15 01:00:00   4135001  ...          22.165423          0.0
# ...                  ...       ...  ...                ...          ...
# 3254 2020-06-17 22:45:00   4136001  ...          22.856201          0.0
# 3255 2020-06-17 23:00:00   4136001  ...          22.744190          0.0
# 3256 2020-06-17 23:15:00   4136001  ...          22.492245          0.0
# 3257 2020-06-17 23:30:00   4136001  ...          22.373909          0.0
# 3258 2020-06-17 23:45:00   4136001  ...          22.535908          0.0
#
# [6441 rows x 6 columns]

# %%
# Filter for specific columns because of duplicates and unneeded columns
power_data_1 = power_data_1[['DATE_TIME', 'DC_POWER', 'SOURCE_KEY', 'PLANT_ID']]
weather_data_1 = weather_data_1[['DATE_TIME', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE']]

power_data_2 = power_data_2[['DATE_TIME', 'DC_POWER', 'SOURCE_KEY', 'PLANT_ID']]
weather_data_2 = weather_data_2[['DATE_TIME', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE']]

# Merge the power and weather data based on the date and time
merged_data_1 = pd.merge(power_data_1, weather_data_1, on='DATE_TIME', how='inner')
merged_data_2 = pd.merge(power_data_2, weather_data_2, on='DATE_TIME', how='inner')

merged_data = pd.concat([merged_data_1, merged_data_2])

display(merged_data)
# Out:
#                 DATE_TIME  DC_POWER  ... AMBIENT_TEMPERATURE  MODULE_TEMPERATURE
# 0     2020-05-15 00:00:00       0.0  ...           25.184316           22.857507
# 1     2020-05-15 00:00:00       0.0  ...           25.184316           22.857507
# 2     2020-05-15 00:00:00       0.0  ...           25.184316           22.857507
# 3     2020-05-15 00:00:00       0.0  ...           25.184316           22.857507
# 4     2020-05-15 00:00:00       0.0  ...           25.184316           22.857507
# ...                   ...       ...  ...                 ...                 ...
# 67693 2020-06-17 23:45:00       0.0  ...           23.202871           22.535908
# 67694 2020-06-17 23:45:00       0.0  ...           23.202871           22.535908
# 67695 2020-06-17 23:45:00       0.0  ...           23.202871           22.535908
# 67696 2020-06-17 23:45:00       0.0  ...           23.202871           22.535908
# 67697 2020-06-17 23:45:00       0.0  ...           23.202871           22.535908
#
# [136472 rows x 7 columns]

# %% [markdown]
# Final merged dataframe is contained in the merged_data variable

# %% [markdown]
# Task 2 code

# %%
# Pick a date range, I just did the first 5 days
START_DATE = pd.to_datetime("2020-05-15 00:00:00")
END_DATE = pd.to_datetime("2020-05-20 00:00:00")

# Pick an inverter, I just did the first one
INVERTER_ID = "1BY6WEcLGh8j5v7"

# Filter for the specific conditions above
one_inverter_5_day = merged_data[
    (merged_data['SOURCE_KEY'] == INVERTER_ID) &
    (merged_data['DATE_TIME'] > START_DATE) &
    (merged_data['DATE_TIME'] < END_DATE)
]

fig, ax = plt.subplots(figsize = (15, 5))
ax.set_title(f'DC Power out over time, with weather patterns (filtered for source with id: {INVERTER_ID})')

# DC Power out as main variable
color = 'blue'
ax.plot(one_inverter_5_day.DATE_TIME, one_inverter_5_day.DC_POWER, color = color)
ax.set_xlabel('Date')
ax.set_ylabel('DC power out (kW)', color = color)

# Irradiation as second
color = 'orange'
ax2 = ax.twinx()
ax2.plot(one_inverter_5_day.DATE_TIME, one_inverter_5_day.IRRADIATION, color = color)
ax2.set_ylabel('Irradiation', color = color)

# Ambient temperature as third variable
color = 'green'
ax3 = ax.twinx()
ax3.plot(one_inverter_5_day.DATE_TIME, one_inverter_5_day.AMBIENT_TEMPERATURE, color = color)
ax3.set_ylabel('Ambient Temperature (C)', color = color)
ax3.spines['right'].set_position(('outward', 60))

plt.show()

# %% [markdown]
# Task 3 code

# %% [markdown]
# Graphed seperately because of differing scales

# %%
# Simple scatter plots, small points and low alpha because of the sheer amount of data
fig_1, axes_1 = plt.subplots()
axes_1.scatter(merged_data_1.IRRADIATION, merged_data_1.DC_POWER, alpha=0.1, s=1)
axes_1.set_title("DC Power out wrt Irradiation (Scatter Plot, plant 1)")
axes_1.set_xlabel("Irradiation (unknown unit)")
axes_1.set_ylabel("DC power out (kW)")

fig_2, axes_2 = plt.subplots()
axes_2.scatter(merged_data_2.IRRADIATION, merged_data_2.DC_POWER, alpha=0.1, s=1)
axes_2.set_title("DC Power out wrt Irradiation (Scatter Plot, plant 2)")
axes_2.set_xlabel("Irradiation (unknown unit)")
axes_2.set_ylabel("DC power out (kW)")

plt.show()

# %%
# Filter for when there is no power but irradiation is significant (likely equipment failure)
filtered_for_error = merged_data[(merged_data['DC_POWER'] == 0.0) & (merged_data['IRRADIATION'] > 0.5)]

# Get a list of all the timestamps
timestamps = filtered_for_error[['DATE_TIME']]

# Convenient textual form is a list of times and how many inverters were failed at that time
ts_count = timestamps.groupby(timestamps.columns.tolist(), as_index=False).size()
display(ts_count)
# Out:
#               DATE_TIME  size
# 0   2020-05-15 09:45:00     4
# 1   2020-05-15 10:00:00     4
# 2   2020-05-15 10:15:00     7
# 3   2020-05-15 10:30:00     7
# 4   2020-05-15 10:45:00     7
# ..                  ...   ...
# 531 2020-06-15 14:00:00     2
# 532 2020-06-16 11:45:00     4
# 533 2020-06-16 12:00:00     3
# 534 2020-06-16 12:45:00     1
# 535 2020-06-16 14:30:00    22
#
# [536 rows x 2 columns]

# %% [markdown]
# Task 4 code: Exploratory Data Analysis

# %%
print("Data types: ")
print(merged_data.info()) # look at data types
print()
print("Null value counts: ")
print(merged_data.isnull().sum()) # check for null values
print()
print("Duplicate value count: ")
print(merged_data.duplicated().sum()) # check for duplicates
# Data is clean so move on to analysis
# Out:
# Data types:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136472 entries, 0 to 67697
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   DATE_TIME            136472 non-null  datetime64[ns]
#  1   DC_POWER             136472 non-null  float64
#  2   SOURCE_KEY           136472 non-null  object
#  3   PLANT_ID             136472 non-null  int64
#  4   IRRADIATION          136472 non-null  float64
#  5   AMBIENT_TEMPERATURE  136472 non-null  float64
#  6   MODULE_TEMPERATURE   136472 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 8.3+ MB
# None
#
# Null value counts:
# DATE_TIME              0
# DC_POWER               0
# SOURCE_KEY             0
# PLANT_ID               0
# IRRADIATION            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# dtype: int64
#
# Duplicate value count:
# 0

# %%
merged_data.describe() # show basic statistics
# Out:
#                            DATE_TIME  ...  MODULE_TEMPERATURE
# count                         136472  ...       136472.000000
# mean   2020-06-01 09:22:57.605662464  ...           31.920744
# min              2020-05-15 00:00:00  ...           18.140415
# 25%              2020-05-23 23:00:00  ...           22.411698
# 50%              2020-06-01 18:45:00  ...           26.413755
# 75%              2020-06-09 21:45:00  ...           40.778583
# max              2020-06-17 23:45:00  ...           66.635953
# std                              NaN  ...           11.803674
#
# [8 rows x 6 columns]

# %%
def show_distributions(df: pd.DataFrame, idx: str):
  # Plot distribution of a specific column
  sns.histplot(df[idx], kde=True)
  plt.title(idx + ' Distribution')
  plt.show()

  # Box plot to detect outliers
  sns.boxplot(x=df[idx])
  plt.title(idx + ' Box Plot')
  plt.show()

# %%
def show_relationship(df: pd.DataFrame, x: str, y: str):
  sns.scatterplot(data=df, x=x, y=y)
  plt.title(x + ' VS ' + y)
  plt.show()
  print('Correlation ' + df[x].corr(df[y]))

# %%
merged_data['DC_POWER_NORM'] = merged_data.groupby('SOURCE_KEY')['DC_POWER'].transform(
    lambda x: (x - x.min()) / (x.max() - x.min()) if (x.max() - x.min()) != 0 else 0
) # Normalize DC_POWER as a percent of max power seen by specific inverter

merged_data['HOUR_OF_DAY'] = merged_data['DATE_TIME'].dt.hour # Extract the hour of day as a feature
merged_data['TEMP_DIFF'] = merged_data['MODULE_TEMPERATURE'] - merged_data['AMBIENT_TEMPERATURE'] # How much hotter the module is than the ambient temperature

merged_data_nonzero_power = merged_data[merged_data['DC_POWER'] > 0] # Dataset strictly of datapoints where DC_POWER is nonzero, since I seem to use it a lot

# %%
merged_data_numerical = merged_data.select_dtypes(include=[np.number])[['DC_POWER', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'TEMP_DIFF']] # cant correlate non numerical fields
p_matrix = merged_data_numerical.corr(method=lambda x, y: pearsonr(x, y)[1]) # get p-value matrix
r_matrix = merged_data_numerical.corr() # get r value matrix

mask = np.triu(np.ones_like(r_matrix, dtype=bool))

labels = np.asarray(
    [
        f"r: {r:.2f}\np: {p:.3f}" for r, p in
        zip(r_matrix.values.flatten(), p_matrix.values.flatten())
    ]
  ).reshape(r_matrix.shape)
sns.heatmap(r_matrix, annot=labels, fmt="", cmap="coolwarm", vmin=-1, vmax=1, cbar=True, mask=mask)
plt.title("Correlation Matrix with P-Values")
plt.show()

# %%
# %%script echo "Cell disabled due to long runtime"
# features = ['DC_POWER', 'IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'TEMP_DIFF', 'PLANT_ID']
# sns.pairplot(merged_data[features], diag_kind='kde', kind='reg', hue='PLANT_ID', plot_kws={
#                  'line_kws': {'color': 'black'},
#                  'scatter_kws': {'s': 1, 'alpha': 0.1}
#              })
# plt.show()
# Out:
# Cell disabled due to long runtime

# %%
plt.subplots(figsize=(15,5))

sns.boxplot(data=merged_data_nonzero_power, x='SOURCE_KEY', y='DC_POWER_NORM', palette='viridis', hue='SOURCE_KEY', legend=False)

plt.title('DC Power Distribution per Inverter')
plt.xticks(rotation=90)
plt.ylabel('Normalized DC Power')
plt.xlabel('Inverter ID (SOURCE_KEY)')
plt.show()

# %%
# Plot daily average production profiles
sns.lineplot(data=merged_data, x='HOUR_OF_DAY', y='DC_POWER', hue='PLANT_ID')
plt.title("Average Daily Power Profile")
plt.show()

# %%
show_distributions(merged_data, 'DC_POWER')

# %% [markdown]
# High number of zeroes, due to night time, what if we filter those out?

# %%
show_distributions(merged_data_nonzero_power, 'DC_POWER')

# %% [markdown]
# Might be a log distribution, try plotting ln('DC_POWER')

# %%
merged_data_filtered_with_power_log = merged_data_nonzero_power.copy()
merged_data_filtered_with_power_log['DC_POWER'] = np.log(merged_data_filtered_with_power_log['DC_POWER'])
show_distributions(merged_data_filtered_with_power_log, 'DC_POWER')

# %% [markdown]
# Looks like two peak distribution, so there are likely two states the panels like to hover around (plant 1 vs plant 2?), excluding zero power output

# %%
merged_data_1_filtered = merged_data_1[merged_data_1['DC_POWER'] > 0].copy()
show_distributions(merged_data_1_filtered, 'DC_POWER')

merged_data_2_filtered = merged_data_2[merged_data_2['DC_POWER'] > 0].copy()
show_distributions(merged_data_2_filtered, 'DC_POWER')

# %% [markdown]
# Task 5 code: Train Test split

# %%
from sklearn.model_selection import train_test_split

# %%
x = merged_data_nonzero_power[['IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'HOUR_OF_DAY', 'TEMP_DIFF']]
y = merged_data_nonzero_power['DC_POWER_NORM']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=69420)
display(x_test, y_test)
# Out:
#        IRRADIATION  AMBIENT_TEMPERATURE  ...  HOUR_OF_DAY  TEMP_DIFF
# 7155      0.587753            27.324890  ...            9  10.457280
# 65072     0.027035            27.803932  ...           18   0.778928
# 64850     0.409412            29.934204  ...           15   8.419578
# 57079     0.559178            25.460364  ...           10  11.924915
# 66071     0.161417            27.426601  ...           16   4.032974
# ...            ...                  ...  ...          ...        ...
# 47949     0.661846            34.643022  ...           15  14.764397
# 16003     0.816838            28.602547  ...           10  20.482188
# 57636     0.181062            26.854547  ...           16   3.996401
# 55397     0.433010            28.499876  ...           15  12.364899
# 26904     0.291289            32.676328  ...           16   6.017550
#
# [13772 rows x 5 columns]
# 7155     0.628367
# 65072    0.025052
# 64850    0.443609
# 57079    0.572618
# 66071    0.151909
#            ...
# 47949    0.689397
# 16003    0.607138
# 57636    0.184494
# 55397    0.455872
# 26904    0.262021
# Name: DC_POWER_NORM, Length: 13772, dtype: float64

# %% [markdown]
# Task 6 code: Linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
# %%script echo "Cell disabled due to long runtime"
# model = LinearRegression()
#
# model.fit(x_train[['IRRADIATION']], y_train)
#
# y_pred = model.predict(x_test[['IRRADIATION']])
#
# sns.scatterplot(x=x_test.IRRADIATION, y=y_test, color='blue', alpha=0.7, label='Actual Values', s=5)
# sns.lineplot(x=x_test.IRRADIATION, y=y_pred, color='orange', label='Predicted')
#
# plt.show()
# Out:
# Cell disabled due to long runtime

# %% [markdown]
# Data cleaning techniques:

# %%
from scipy import stats
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
FEATURES = ['IRRADIATION', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'HOUR_OF_DAY', 'TEMP_DIFF']

# %%
def split_standard(x, y):
  return train_test_split(x, y, test_size=0.2, random_state=69420)
def split_chronological(x, y):
  return train_test_split(x, y, test_size=0.2, random_state=69420, shuffle=False)
def scale(train_x_df: pd.DataFrame, test_x_df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
  scaler = StandardScaler()
  train_x_scaled = scaler.fit_transform(train_x_df)
  test_x_scaled = scaler.transform(test_x_df)
  return pd.DataFrame(train_x_scaled, columns=train_x_df.columns, index=train_x_df.index), pd.DataFrame(test_x_scaled, columns=test_x_df.columns, index=test_x_df.index)

# %%
def clean_zscore(df: pd.DataFrame, y_series: pd.Series) -> tuple[pd.DataFrame, pd.Series]:
  z_scores = np.abs(stats.zscore(df))
  threshold = 3.0
  mask = (z_scores < threshold).all(axis=1)
  df_clean = df[mask]
  y_clean = y_series[mask]
  return df_clean, y_clean

# %%
def modified_zscore(col: pd.Series) -> float:
    median = col.median()
    mad = np.median(np.abs(col - median))

    if mad == 0:
        return np.zeros(len(col))

    return 0.6745 * (col - median) / mad

def clean_modified_zscore(df: pd.DataFrame, y_series: pd.Series) -> tuple[pd.DataFrame, pd.Series]:
  mod_z_scores = np.abs(df.apply(modified_zscore))
  threshold = 3.5
  mask = (mod_z_scores < threshold).all(axis=1)
  df_clean = df[mask]
  y_clean = y_series[mask]
  return df_clean, y_clean

# %%
def clean_iqr(df: pd.DataFrame, y_series: pd.Series) -> tuple[pd.DataFrame, pd.Series]:
  cols = df

  Q1 = cols.quantile(0.25)
  Q3 = cols.quantile(0.75)
  IQR = Q3 - Q1

  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

  mask = ((cols >= lower_bound) & (cols <= upper_bound)).all(axis=1)
  df_clean = df[mask]
  y_clean = y_series[mask]
  return df_clean, y_clean

# %%
def clean_isolation_forest(df: pd.DataFrame, y_series: pd.Series) -> tuple[pd.DataFrame, pd.Series]:
  detector = IsolationForest(contamination="auto", random_state=676767)
  detector.fit(df)

  predictions = detector.predict(df)

  mask = (predictions == 1)
  df_clean = df[mask]
  y_clean = y_series[mask]
  return df_clean, y_clean

# %% [markdown]
# Models:

# %%
from sklearn.ensemble import RandomForestRegressor

def fit_random_forest(x: pd.DataFrame, y: pd.Series):
  model = RandomForestRegressor(n_estimators=100, random_state=42069420)
  model.fit(x, y)
  return model

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
def fit_hist_gradient(x: pd.DataFrame, y: pd.Series):
  model = HistGradientBoostingRegressor(random_state=696969)
  model.fit(x, y)
  return model

# %%
from sklearn.linear_model import Ridge
def fit_ridge(x: pd.DataFrame, y: pd.Series):
  model = Ridge(alpha=1.0)
  model.fit(x, y)
  return model

# %%
from sklearn.svm import SVR
def fit_svr(x: pd.DataFrame, y: pd.Series):
  model = SVR(kernel='rbf')
  model.fit(x, y)
  return model

# %%
# %%script echo "Cell disabled due to long runtime"
#
# from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
#
# split_funcs = [split_standard, split_chronological]
# clean_funcs = [clean_iqr, clean_zscore, clean_modified_zscore, clean_isolation_forest]
# fit_funcs = [fit_hist_gradient, fit_random_forest, fit_ridge, fit_svr]
#
# res = []
#
# for split_func in split_funcs:
#   data = merged_data.copy()
#   x = data[FEATURES]
#   y = data['DC_POWER_NORM']
#
#   train_x_initial, test_x_initial, train_y_initial, test_y_initial = split_func(x, y)
#
#   for clean_func in clean_funcs:
#     train_x_cleaned, train_y_cleaned = clean_func(train_x_initial.copy(), train_y_initial.copy())
#
#     scaled_train_x, scaled_test_x = scale(train_x_cleaned, test_x_initial)
#
#     for fit_func in fit_funcs:
#       model = fit_func(scaled_train_x, train_y_cleaned)
#
#       pred_y = model.predict(scaled_test_x)
#
#       rmse = root_mean_squared_error(test_y_initial, pred_y)
#       mae = mean_absolute_error(test_y_initial, pred_y)
#       r2 = r2_score(test_y_initial, pred_y)
#
#       res.append({
#         "RMSE": rmse,
#         "MAE": mae,
#         "R2": r2,
#         "Data clean": clean_func.__name__,
#         "Split": split_func.__name__,
#         "Fit": fit_func.__name__
#       })
#
# res = pd.DataFrame(res)
# res = res.sort_values(by="RMSE", ascending=True)
#
# res = res.reset_index(drop=True)
#
# display(res)
# Out:
# Cell disabled due to long runtime

# %% [markdown]
# Feature importances:

# %%
from sklearn.inspection import permutation_importance

FEATURES = ['IRRADIATION', 'MODULE_TEMPERATURE', 'HOUR_OF_DAY', 'TEMP_DIFF', 'AMBIENT_TEMPERATURE']
fit_funcs = [fit_hist_gradient, fit_random_forest, fit_ridge, fit_svr]

data = merged_data.copy()
x = data[FEATURES]
y = data['DC_POWER_NORM']

train_x_initial, test_x_initial, train_y_initial, test_y_initial = split_standard(x, y)
train_x_cleaned, train_y_cleaned = clean_zscore(train_x_initial.copy(), train_y_initial.copy())
scaled_train_x, scaled_test_x = scale(train_x_cleaned, test_x_initial)

hist_gradient = HistGradientBoostingRegressor(random_state=696969)
random_forest = RandomForestRegressor(n_estimators=100, random_state=42069420)

hist_gradient.fit(scaled_train_x, train_y_cleaned)
random_forest.fit(scaled_train_x, train_y_cleaned)

importances = pd.DataFrame({
    'Feature': FEATURES,
    'Importance': random_forest.feature_importances_
}).sort_values(by='Importance', ascending=False)

sns.barplot(
    data=importances,
    x='Importance',
    y='Feature',
    hue='Feature',
    palette='viridis',
    legend=False
)
plt.title("Random forest built in importance")
plt.show()

for fit_func in fit_funcs:
  model = fit_func(scaled_train_x, train_y_cleaned)

  permutation_importance_out = permutation_importance(model, scaled_test_x, test_y_initial, n_repeats=10, random_state=69420)

  df_permutation_importances = pd.DataFrame({
    'Feature': FEATURES,
    'Importance Mean': permutation_importance_out.importances_mean,
    'Importance Std': permutation_importance_out.importances_std
  }).sort_values(by='Importance Mean', ascending=False)

  sns.barplot(
    data=df_permutation_importances,
    x='Importance Mean',
    y='Feature',
    hue='Feature',
    palette='viridis',
    legend=False
  )
  plt.title(f"{fit_func.__name__} permutation importance")
  plt.show()
